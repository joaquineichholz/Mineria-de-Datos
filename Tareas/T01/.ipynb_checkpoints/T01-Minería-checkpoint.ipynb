# %%
import numpy as np
import pandas as pd
from datetime import datetime
from itertools import chain
from collections import defaultdict
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
def join_conjunto_sets2(conjuntos, muertes):
    aux = []
    nuevo_conjunto = []
    siguiente_conjunto = 1
    tiempo = datetime.now()
    
    for A in conjuntos[:-1]:
        for B in conjuntos[siguiente_conjunto:]:
            if A - {max(A)} == B - {max(B)}:
                posible = A.union(B)
                muere = False
                aux.append(posible)
                for muerte in muertes:
                    if muerte.issubset(posible):
                        muere = True
                        break
                if not muere:
                    nuevo_conjunto.append(posible)
            else:
                continue

        siguiente_conjunto += 1    
    
    return nuevo_conjunto

# %%
def conjuntos_sobre_umbral_sets(cancion_esta_en, conjuntos, frec_min):
    
    sobrevivientes = []
    muertes = []
    
    diccionario = defaultdict(int)
    aux_cancion_esta_en = defaultdict(set)

    for conjunto in conjuntos:
        setlist = []
        canciones = []
        
        for cancion in conjunto:
            setlist.append(cancion_esta_en[cancion])
            canciones.append(cancion)
        
        repeticiones = len(set.intersection(*setlist))
        if repeticiones >= frec_min:
            sobrevivientes.append((conjunto, repeticiones))
        else:
            muertes.append(conjunto)
    #print(sobrevivientes)

    return sobrevivientes, muertes

# %%
def fit(frec_min, datos='spotify.npy'):
    
    data = np.load(datos)
    #listas_datos = [set(x) for x in dict(data.item()).values()]
    
    listas_datos = {x[0]: set(x[1]) for x in dict(data.item()).items()}
    
    frec_min = frec_min * len(listas_datos)
    
    
    canciones = [x for songs in listas_datos.values() for x in songs]
    orden = list(set(canciones))

    enumeracion_canciones = dict(enumerate(orden))  # {0: cancion1, 1: cancion2}...
    canciones_enumeracion = {x[1]: x[0] for x in enumeracion_canciones.items()}  # {cancion1: 0, cancion2: 1... }
       
    playlist = {dato[0]: sorted([canciones_enumeracion[x] for x in dato[1]]) for dato in listas_datos.items()}



    '''####################
    
    data = {0:[1, 2, 5], 1:[2, 4], 2:[2, 3], 3:[1, 2, 4], 4:[1, 3], 5:[2, 3], 
                                              6:[1, 3], 7:[1, 2, 3, 5], 8:[1, 2, 3]}
    #print(data)
    listas_datos = {x[0]: set(x[1]) for x in data.items()}
    # {0: {1, 2, 5}, 1: {2, 4}, 2: {2, 3}, 3: {1, 2, 4}, 4: {1, 3}, 5: {2, 3}, 6: {1, 3}, 7: {1, 2, 3, 5}, 8: {1, 2, 3}}
    
    canciones = [x for songs in listas_datos.values() for x in songs]
    orden = list(set(canciones))
    
    enumeracion_canciones = dict(enumerate(orden))  # {0: cancion1, 1: cancion2}...
    canciones_enumeracion = {x[1]: x[0] for x in enumeracion_canciones.items()}  # {cancion1: 0, cancion2: 1... }
        
    playlist = {dato[0]: sorted([canciones_enumeracion[x] for x in dato[1]]) for dato in listas_datos.items()}

    conjuntos = [{x} for x in canciones_enumeracion.values()]
    
    ####################'''
    

    # seleccionar elementos sobre el umbral  
    
    diccionario = defaultdict(int)
    total = chain(*playlist.values())
    

    t = datetime.now()
    for x in total:
        diccionario[x] += 1

    #print('diccionario frec tardo {} seg\n'.format((datetime.now() - t).total_seconds()))

    conjuntos = [{x[0]} for x in (filter(lambda x: x[1] >= frec_min, diccionario.items()))]
    t = datetime.now()
    
    # seleccionar listas que posean elementos de interés
    #tuplas = []
    #diccionario_playlists = defaultdict(list) # {lista: [canciones]}
    cancion_esta_en = defaultdict(set) # {(canciones): [listas]}
    for indice, lista  in playlist.items():
        for conjunto in conjuntos:
            if conjunto.issubset(lista):
                #diccionario_playlists[indice].append(*conjunto)
                cancion_esta_en[min(conjunto)].add(indice)
                #tuplas.append(lista)

    retorno = []
    k = 2
    #print('diccionario frec tardo {} seg\n'.format((datetime.now() - t).total_seconds()))
    
    
    muerte = []
    listas = conjuntos
    aux = []
    for conjunto in listas:
        l = set()
        l.add(enumeracion_canciones[min(conjunto)])
        aux.append((l, len(cancion_esta_en[min(conjunto)])))

    retorno.extend(aux)

    while True: 
        t = datetime.now()
        
        conjuntos = join_conjunto_sets2(listas, muerte)
        #print('{}: join tardo {} seg'.format(k, (datetime.now() - t).total_seconds()))
        listas, muerte = conjuntos_sobre_umbral_sets(cancion_esta_en, conjuntos, frec_min)
        repeticiones = [x[1] for x in listas]
        listas = [x[0] for x in listas]
        t = datetime.now()
        #print('{}: conjuntos sobre umbral tardo {} seg\n'.format(k, (datetime.now() - t).total_seconds()))

        if not listas:  
            return retorno
        
        else:
            aux = []
            for conjunto in range(len(listas)):
                l = set()
                for dato in listas[conjunto]:
                    l.add((enumeracion_canciones[dato]))
                aux.append((l, repeticiones[conjunto]))

            retorno.extend(aux)

# %%
t = 0
tiempo = datetime.now()
a = fit(0.02)

t += (datetime.now() - tiempo).total_seconds()
print('tiempo promedio:', t)
# Out:
# tiempo promedio: 3.187848

# %%
for x in a:
    print(x)
# Out:
# ({"It Wasn't Me"}, 218)
# ({'Say My Name'}, 266)
# ({'Yeah!'}, 238)
# ({'Hey Ya! - Radio Mix / Club Mix'}, 203)
# ({'Closer'}, 723)
# ({'Mr. Brightside'}, 248)
# ({'Forever'}, 321)
# ({'Party In The U.S.A.'}, 211)
# ({'Home'}, 454)
# ({'No Role Modelz'}, 311)
# ({'Stronger'}, 258)
# ({"Don't Stop Believin'"}, 261)
# ({'Ignition - Remix'}, 310)
# ({'Bohemian Rhapsody - Remastered 2011'}, 240)
# ({'Lean On (feat. MØ & DJ Snake)'}, 265)
# ({'All I Want'}, 221)
# ({'Riptide'}, 332)
# ({'Trouble'}, 216)
# ({'Intro'}, 215)
# ({'Mercy'}, 305)
# ({'Gravity'}, 200)
# ({'Sober'}, 247)
# ({'One Dance'}, 411)
# ({'My Girl'}, 286)
# ({'Body Like A Back Road'}, 267)
# ({'Redbone'}, 281)
# ({"Sweet Child O' Mine"}, 205)
# ({'Sweet Home Alabama'}, 207)
# ({'Crazy'}, 208)
# ({'Despacito - Remix'}, 282)
# ({"I'm the One"}, 319)
# ({'Jungle'}, 220)
# ({'Hello'}, 289)
# ({'V. 3005'}, 221)
# ({'Uptown Funk'}, 231)
# ({'CAN\'T STOP THE FEELING! (Original Song from DreamWorks Animation\'s "TROLLS")'}, 205)
# ({'Hold On'}, 225)
# ({'Angel'}, 218)
# ({'Unforgettable'}, 326)
# ({'Waves'}, 242)
# ({'Low Life'}, 237)
# ({'Black Beatles'}, 285)
# ({'Bounce Back'}, 297)
# ({'XO TOUR Llif3'}, 323)
# ({'Deja Vu'}, 245)
# ({'goosebumps'}, 308)
# ({'Congratulations'}, 403)
# ({'Bank Account'}, 230)
# ({'Jumpman'}, 287)
# ({'Paris'}, 259)
# ({'Ni**as In Paris'}, 275)
# ({'X (feat. Future)'}, 204)
# ({"F**kin' Problems"}, 228)
# ({'White Iverson'}, 304)
# ({'Something Just Like This'}, 216)
# ({'Believer'}, 246)
# ({'Stay (with Alessia Cara)'}, 212)
# ({'Die A Happy Man'}, 209)
# ({'Let It Go'}, 275)
# ({'Blessings'}, 260)
# ({'Hallelujah'}, 268)
# ({'Skinny Love'}, 257)
# ({'Caroline'}, 390)
# ({'Too Good'}, 202)
# ({'Famous'}, 207)
# ({'Fake Love'}, 297)
# ({'Chicken Fried'}, 214)
# ({'Radioactive'}, 229)
# ({"That's What I Like"}, 261)
# ({'Come On Eileen'}, 204)
# ({'Shape of You'}, 310)
# ({"Say You Won't Let Go"}, 200)
# ({'Say It'}, 271)
# ({'T-Shirt'}, 351)
# ({'Starboy'}, 281)
# ({'Never Be Like You'}, 230)
# ({'Alone'}, 206)
# ({'Monster'}, 218)
# ({'Alright'}, 263)
# ({'Selfish'}, 242)
# ({'Slide'}, 318)
# ({'September'}, 259)
# ({"Ain't No Mountain High Enough"}, 222)
# ({'Kids'}, 200)
# ({'Gold'}, 369)
# ({'Down'}, 287)
# ({'Let Me Love You'}, 382)
# ({'Stay'}, 339)
# ({"Can't Feel My Face"}, 222)
# ({"i hate u, i love u (feat. olivia o'brien)"}, 200)
# ({'Swang'}, 219)
# ({'With You'}, 222)
# ({'Location'}, 323)
# ({'1-800-273-8255'}, 264)
# ({"Don't"}, 305)
# ({'Roses'}, 424)
# ({'Hurricane'}, 284)
# ({'What Do You Mean?'}, 216)
# ({'Middle'}, 227)
# ({'Sorry'}, 318)
# ({'Cheap Thrills'}, 209)
# ({'Shut Up and Dance'}, 222)
# ({'Thinking Out Loud'}, 234)
# ({'Summer'}, 202)
# ({'Young Dumb & Broke'}, 219)
# ({'Paradise'}, 222)
# ({'All of Me'}, 235)
# ({'Sugar'}, 203)
# ({'Wagon Wheel'}, 234)
# ({'Cold Water (feat. Justin Bieber & MØ)'}, 234)
# ({'Ride'}, 414)
# ({'Heathens'}, 223)
# ({'Trap Queen'}, 289)
# ({"I Don't Fuck With You"}, 235)
# ({'Fast Car'}, 229)
# ({'Photograph'}, 218)
# ({'HUMBLE.'}, 465)
# ({'Tunnel Vision'}, 247)
# ({'Passionfruit'}, 254)
# ({'rockstar'}, 232)
# ({"Don't Let Me Down"}, 317)
# ({'Let Her Go'}, 227)
# ({'Panda'}, 307)
# ({'Broccoli (feat. Lil Yachty)'}, 399)
# ({'Slippery (feat. Gucci Mane)'}, 236)
# ({'No Problem (feat. Lil Wayne & 2 Chainz)'}, 321)
# ({'Bad and Boujee (feat. Lil Uzi Vert)'}, 345)
# ({'Mask Off'}, 316)
# ({'DNA.'}, 231)
# ({'Antidote'}, 260)
# ({'Stressed Out'}, 223)
# ({'Me, Myself & I'}, 245)
# ({'I Took A Pill In Ibiza - Seeb Remix'}, 219)
# ({'No Diggity'}, 203)
# ({'Chill Bill'}, 228)
# ({'Work'}, 261)
# ({'You'}, 233)
# ({'iSpy (feat. Lil Yachty)'}, 331)
# ({'Hotline Bling'}, 265)
# ({'679 (feat. Remy Boyz)'}, 244)
# ({'The Hills'}, 273)
# ({'Work from Home'}, 217)
# ({'Needed Me'}, 238)
# ({'Controlla'}, 206)
# ({'Wake Up'}, 212)
# ({'My House'}, 209)
# ({'Believe'}, 211)
# ({'Love Yourself'}, 217)
# ({'Alive'}, 224)
# ({'This Is What You Came For'}, 215)
# ({'Drive'}, 234)
# ({'Again'}, 212)
# ({'Gold Digger'}, 285)
# ({"I'm Yours"}, 242)
# ({'XO TOUR Llif3', 'HUMBLE.'}, 204)
# ({'Congratulations', 'HUMBLE.'}, 214)
# ({'Mask Off', 'HUMBLE.'}, 204)

# %%
def fconfianza(subconjunto, conjunto, n):
    sub = 0
    conj = 0
    for lista in listas:
        if subconjunto.issubset(lista):
            sub += 1
        if conjunto.issubset(lista):
            conj += 1
    return con / sub
        
            

def fsoporte(conjunto, listas):
    conj = 0
    n = 0
    for lista in listas:
        if conjunto.issubset(lista):
            conj += 1
        n += 1
    return conj / n


def subsets(conjunto):
    retorno = []
    listas = list(conjunto)

    def backtrack(i=0):            
        if i == len(listas):
            yield set(retorno)
            
        
        else:
            yield from backtrack(i + 1)
            retorno.append(listas[i])
            
            yield from backtrack(i + 1)
            retorno.pop()

    yield from backtrack()
    
    
    
def generate(frecuentes, n):        
    table = []
    encabezado = ['conjunto', 'subconjunto', 'confianza', 'soporte', 'lift']
    conj_repetidos = []
    sub_repetidos = []
    for x in frecuentes:
        if len(x[0]) > 1:
            print(x)
    print()

    for conjunto in sorted(frecuentes, key=lambda x: len(x[0])):
        if len(conjunto[0]) == 1:
            if conjunto[0] in conj_repetidos:
                continue
            confianza = 1
            soporte = conjunto[1] / n        
            lift =  confianza / soporte
            #table.append(['  |  '.join(list(conjunto[0])), '         ', str(round(confianza, 3)), str(round(soporte, 3)), str(round(lift, 3))])

        else:
            elementos = conjunto[0] # {'HUMBLE.', 'XO TOUR Llif3'}
            frec = conjunto[1]
            subset = list(subsets(elementos)) # [set(), {'XO TOUR Llif3'}, {'HUMBLE.'}, {'HUMBLE.', 'XO TOUR Llif3'}]
                
            for conjunt in range(len(subset)): # 4
                if subset[conjunt]: # != set()
                    for A in elementos:
                        conj = elementos - {A}
                        sub = {A}
                        if conj in conj_repetidos and sub in sub_repetidos:
                            continue

                        conj_repetidos.append(conj)
                        sub_repetidos.append(sub)
                        if conj:
                            frec_conj = 0
                            frec_sub = 0
                            for x in frecuentes:
                                if x[0] == sub:
                                    print(x[0] ,'==', sub)
                                    frec_sub = x[1]
                                if x[0] == conj:
                                    frec_conj = x[1]
                            print('conj', conj)
                            print('sub', sub)
                            confianza = [frec_conj / frec_sub if frec_conj / frec_sub <= 1 else frec_sub / frec_conj][0]
                            soporte = frec_conj / n
                            lift =  confianza / soporte
                            print('soporte', soporte)
                            print('conf', confianza)
                            print()
                            table.append(['  |  '.join(list(conj)), '   |  '.join(list(sub)), str(round(confianza, 3)), str(round(soporte, 3)), str(round(lift, 3))])

    with open('resultado.csv', 'w') as resultados:
        df =  pd.DataFrame(sorted(table, key=lambda x: x[3], reverse=True), columns=encabezado)
        resultados.write(df.to_string(index=False))

            
    return table
data = np.load('spotify.npy')  
listas_datos = [x for x in dict(data.item()).items()]
    
datos = generate(a, len(listas_datos))
# Out:
# ({'XO TOUR Llif3', 'HUMBLE.'}, 204)
# ({'Congratulations', 'HUMBLE.'}, 214)
# ({'Mask Off', 'HUMBLE.'}, 204)
#
# {'XO TOUR Llif3'} == {'XO TOUR Llif3'}
# conj {'HUMBLE.'}
# sub {'XO TOUR Llif3'}
# soporte 0.0465
# conf 0.6946236559139785
#
# {'HUMBLE.'} == {'HUMBLE.'}
# conj {'XO TOUR Llif3'}
# sub {'HUMBLE.'}
# soporte 0.0323
# conf 0.6946236559139785
#
# {'Congratulations'} == {'Congratulations'}
# conj {'HUMBLE.'}
# sub {'Congratulations'}
# soporte 0.0465
# conf 0.8666666666666667
#
# {'HUMBLE.'} == {'HUMBLE.'}
# conj {'Congratulations'}
# sub {'HUMBLE.'}
# soporte 0.0403
# conf 0.8666666666666667
#
# {'Mask Off'} == {'Mask Off'}
# conj {'HUMBLE.'}
# sub {'Mask Off'}
# soporte 0.0465
# conf 0.6795698924731183
#
# {'HUMBLE.'} == {'HUMBLE.'}
# conj {'Mask Off'}
# sub {'HUMBLE.'}
# soporte 0.0316
# conf 0.6795698924731183

# %%
def ranking(datos):
    datos = [[*x[:2], float(x[2]), float(x[3]), float(x[4])] for x in datos]
    
    # top confianza sin 1
    top_confianza = [x for x in list(sorted(datos, key=lambda x: x[2], reverse=True)) if x[2] < 1]
    top_soporte = list(sorted(datos, key=lambda x: x[3], reverse=True))
    top_lift = list(sorted(datos, key=lambda x: x[4], reverse=True))

    pass
ranking(datos)

# %% [raw]
# #### siguiente = 1
#
# for A in conjunto:
#     for x in range(len(conjunto) - 1):
#         a = 0
#         #print({A}, conjunto - set(A))
#     siguiente += 1
#
# def permutationG(conjunto, s, r=[]):
#     if len(s) == len(conjunto):
#         yield s
#
#     for i in conjunto:
#         if i in s:
#             continue
#
#         s  = s + [i]
#         for x in permutationG(conjunto, s, r):
#             print(x)
#             if x not in r:
#                 r.append(x)
#                 yield x
#         s = s[:-1]
#
# conjunto = {'A', 'B', 'C', 'D'}
# for elemento in conjunto:
#     a = list(permutationG(conjunto - {elemento}, []))
#     for x in a:
#         print({elemento}, set(x))

# %%
def combinacion(combinar, lista):


    new_comb=[]

    for x in combinar:
        pto = lista.index(x[len(x)-1]) 
        for j in range(pto,len(lista)):
            if lista[j] not in x and lista[len(lista)-1] not in x:
                new_comb.append(x+lista[j]) 
 
    print(new_comb)
 

    return new_comb #Esta nueva lista se utilizara como parametro al llamar de nuevo la funcion... 

 
lista = [x for x in conjunto]
print(lista)

comb_final=lista

print("COMBINACIONES")

print("++++++++++++++")

 

while len(comb_final)>1:

    comb_final = combinacion(comb_final, lista)
# Out:
# ['B', 'D', 'A', 'C']
# COMBINACIONES
# ++++++++++++++
# ['BD', 'BA', 'BC', 'DA', 'DC', 'AC']
# ['BDA', 'BDC', 'BAC', 'DAC']
# ['BDAC']

# %%
conjunto = {'A', 'B', 'C', 'D'}

def subsets(conjunto, retorno=[]):
    retorno = []
    aux_conjunto = conjunto
    
    for A in list(conjunto):
        #print(conjunto, A)
        nuevo_conjunto = conjunto - {A}
        #print('nuevo:',nuevo_conjunto)
        #agregar = True
        
        #for conjunto in retorno:
            #print(conjunto, '==', nuevo_conjunto, conjunto == nuevo_conjunto )
         #   if conjunto == nuevo_conjunto:
          #      agregar = False
           #     break
                
        #if agregar:
        agregar = True
        if nuevo_conjunto:
            for x in retorno:
                #print(x,'==', nuevo_conjunto, x == nuevo_conjunto)
                if x == nuevo_conjunto:
                    agregar = False
            if agregar:
                retorno.append(conjunto - {A})
            #subset2 = subsets(conjunto - {A}, retorno)
            #print(retorno)

            #if subset2:
             #   retorno.extend(subset2)
    for x in retorno.copy():
        retorno.extend(subsets(x, retorno))
    return retorno
    #print()

a = subsets(conjunto)
for x in a:
    print(x)
# Out:
# {'D', 'A', 'C'}
# {'B', 'A', 'C'}
# {'B', 'D', 'C'}
# {'B', 'D', 'A'}
# {'A', 'C'}
# {'D', 'C'}
# {'D', 'A'}
# {'C'}
# {'A'}
# {'C'}
# {'D'}
# {'A'}
# {'D'}
# {'A', 'C'}
# {'B', 'C'}
# {'B', 'A'}
# {'C'}
# {'A'}
# {'C'}
# {'B'}
# {'A'}
# {'B'}
# {'D', 'C'}
# {'B', 'C'}
# {'B', 'D'}
# {'C'}
# {'D'}
# {'C'}
# {'B'}
# {'D'}
# {'B'}
# {'D', 'A'}
# {'B', 'A'}
# {'B', 'D'}
# {'A'}
# {'D'}
# {'A'}
# {'B'}
# {'D'}
# {'B'}

# %%
not  set()
# Out:
# True
